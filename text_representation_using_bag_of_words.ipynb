# %% [markdown]
# <a href="https://colab.research.google.com/github/bifinbabu/nlp-jupyter-notebook/blob/main/text_representation_using_bag_of_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('spam.csv')
df.head()
# Out:
#   Category                                            Message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.Category.value_counts()
# Out:
# Category
# ham     4825
# spam     747
# Name: count, dtype: int64

# %%
df['spam'] = df['Category'].apply(lambda x: 1 if x == 'spam' else 0)

# %%
df.head()
# Out:
#   Category                                            Message  spam
# 0      ham  Go until jurong point, crazy.. Available only ...     0
# 1      ham                      Ok lar... Joking wif u oni...     0
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...     1
# 3      ham  U dun say so early hor... U c already then say...     0
# 4      ham  Nah I don't think he goes to usf, he lives aro...     0

# %%
# from re import X
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.Message, df.spam, test_size=0.2)

# %%
X_train.shape
# Out:
# (4457,)

# %%
X_test.shape
# Out:
# (1115,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:4]
# Out:
# 5513    Yes. Please leave at  &lt;#&gt; . So that at  ...
# 1233                          1's finish meeting call me.
# 5432                               Thanx a lot 4 ur help!
# 5466    http//tms. widelive.com/index. wml?id=820554ad...
# Name: Message, dtype: object

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train[:4]
# Out:
# 5513    0
# 1233    0
# 5432    0
# 5466    1
# Name: spam, dtype: int64

# %%
X_train[:4][1233]
# Out:
# "1's finish meeting call me."

# %%
y_train[:4]
# Out:
# 5513    0
# 1233    0
# 5432    0
# 5466    1
# Name: spam, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)

X_train_cv
# Out:
# <4457x7750 sparse matrix of type '<class 'numpy.int64'>'
# 	with 59181 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train_cv.shape
# Out:
# (4457, 7750)

# %%
v.get_feature_names_out()[1000:1050]
# Out:
# array(['anyhow', 'anymore', 'anyone', 'anyones', 'anyplaces', 'anythiing',
#        'anythin', 'anything', 'anythingtomorrow', 'anytime', 'anyway',
#        'anyways', 'anywhere', 'apart', 'apartment', 'apes', 'apeshit',
#        'aphex', 'apnt', 'apo', 'apologise', 'apologize', 'app',
#        'apparently', 'appeal', 'appear', 'applebees', 'apples',
#        'application', 'apply', 'applyed', 'appointment', 'appointments',
#        'appreciate', 'appreciated', 'approaches', 'approaching',
#        'appropriate', 'approved', 'apps', 'appt', 'appy', 'april',
#        'aproach', 'apt', 'aquarius', 'ar', 'arab', 'arabian', 'arcade'],
#       dtype=object)

# %%
v.vocabulary_
# Out:
# {'yes': 7694,
#  'please': 5267,
#  'leave': 4073,
#  'at': 1122,
#  'lt': 4268,
#  'gt': 3279,
#  'so': 6304,
#  'that': 6815,
#  'we': 7424,
#  'can': 1642,
#  'finish': 2871,
#  'meeting': 4437,
#  'call': 1618,
#  'me': 4419,
#  'thanx': 6813,
#  'lot': 4232,
#  'ur': 7200,
#  'help': 3418,
#  'http': 3551,
#  'tms': 6935,
#  'widelive': 7517,
#  'com': 1912,
#  'index': 3677,
#  'wml': 7576,
#  'id': 3601,
#  '820554ad0a1705572711': 657,
#  'first': 2885,
#  'true': 7053,
#  'ringtone': 5817,
#  'each': 2521,
#  'moment': 4578,
#  'in': 3654,
#  'day': 2203,
#  'has': 3360,
#  'its': 3778,
#  'own': 5056,
#  'value': 7249,
#  'morning': 4600,
#  'brings': 1523,
#  'hope': 3507,
#  'afternoon': 858,
#  'faith': 2772,
#  'evening': 2678,
#  'luv': 4284,
#  'night': 4792,
#  'rest': 5774,
#  'wish': 7550,
#  'find': 2866,
#  'them': 6827,
#  'all': 917,
#  'today': 6946,
#  'good': 3202,
#  'not': 4842,
#  'watching': 7409,
#  'movie': 4619,
#  'already': 928,
#  'xy': 7666,
#  'wants': 7389,
#  'shop': 6128,
#  'shopping': 6130,
#  'her': 3428,
#  'now': 4857,
#  'rct': 5609,
#  'thnq': 6862,
#  'adrian': 832,
#  'for': 2955,
#  'text': 6792,
#  'rgds': 5801,
#  'vatian': 7261,
#  'send': 6028,
#  'your': 7714,
#  'resume': 5783,
#  'as': 1090,
#  'per': 5162,
#  'request': 5751,
#  'maangalyam': 4308,
#  'alaipayuthe': 902,
#  'been': 1299,
#  'set': 6054,
#  'callertune': 1628,
#  'callers': 1627,
#  'press': 5413,
#  'to': 6939,
#  'copy': 2026,
#  'friends': 3020,
#  'will': 7527,
#  'have': 3373,
#  'two': 7092,
#  'more': 4596,
#  'cartons': 1684,
#  'off': 4907,
#  'and': 969,
#  'is': 3758,
#  'very': 7279,
#  'pleased': 5268,
#  'with': 7558,
#  'shelves': 6100,
#  'ummma': 7130,
#  'after': 857,
#  'check': 1768,
#  'our': 5028,
#  'life': 4116,
#  'begin': 1308,
#  'from': 3036,
#  'qatar': 5538,
#  'pls': 5275,
#  'pray': 5388,
#  'hard': 3350,
#  'hello': 3415,
#  'my': 4679,
#  'boytoy': 1486,
#  'geeee': 3114,
#  'miss': 4521,
#  'you': 7709,
#  'just': 3889,
#  'woke': 7582,
#  'up': 7182,
#  'were': 7470,
#  'here': 3429,
#  'bed': 1292,
#  'cuddling': 2128,
#  'love': 4245,
#  'cds': 1711,
#  '4u': 529,
#  'congratulations': 1980,
#  'awarded': 1173,
#  '500': 535,
#  'of': 4905,
#  'cd': 1709,
#  'gift': 3147,
#  'vouchers': 7335,
#  'or': 4995,
#  '125': 286,
#  'guaranteed': 3282,
#  'freeentry': 3003,
#  '100': 259,
#  'wkly': 7571,
#  'draw': 2463,
#  'xt': 7656,
#  'music': 4669,
#  '87066': 691,
#  'tncs': 6938,
#  'www': 7644,
#  'ldew': 4060,
#  'com1win150ppmx3age16': 1913,
#  'arun': 1089,
#  'transfr': 7025,
#  'amt': 961,
#  'this': 6858,
#  'the': 6819,
#  '2nd': 406,
#  'attempt': 1133,
#  'contract': 2004,
#  'won': 7587,
#  'weeks': 7451,
#  'top': 6989,
#  'prize': 5443,
#  'either': 2567,
#  '1000': 260,
#  'cash': 1687,
#  '200': 343,
#  '09066361921': 227,
#  'roommate': 5846,
#  'also': 931,
#  'dubsack': 2497,
#  'another': 988,
#  'friend': 3019,
#  'may': 4410,
#  'want': 7385,
#  'some': 6318,
#  'plan': 5249,
#  'on': 4950,
#  'bringing': 1522,
#  'extra': 2746,
#  'll': 4177,
#  'tell': 6762,
#  'when': 7490,
#  'they': 6843,
#  'know': 3973,
#  'sure': 6637,
#  're': 5614,
#  'done': 2426,
#  'sorry': 6349,
#  'next': 4781,
#  'space': 6370,
#  'gives': 3163,
#  'everything': 2691,
#  'remember': 5714,
#  'furniture': 3066,
#  'yours': 7718,
#  'if': 3613,
#  'around': 1075,
#  'move': 4616,
#  'it': 3770,
#  'lock': 4191,
#  'locks': 4192,
#  'key': 3932,
#  'jenne': 3828,
#  'yo': 7704,
#  'chad': 1728,
#  'which': 7500,
#  'gymnastics': 3304,
#  'class': 1842,
#  'do': 2393,
#  'wanna': 7383,
#  'take': 6700,
#  'site': 6211,
#  'says': 5949,
#  'christians': 1823,
#  'full': 3056,
#  'hi': 3442,
#  'technical': 6753,
#  'support': 6631,
#  'providing': 5495,
#  'assistance': 1111,
#  'us': 7215,
#  'customer': 2147,
#  'through': 6878,
#  'email': 2584,
#  'ha': 3306,
#  'don': 2425,
#  'did': 2322,
#  'clever': 1854,
#  'but': 1588,
#  'simple': 6189,
#  'thing': 6847,
#  'pears': 5150,
#  'other': 5021,
#  'perfect': 5166,
#  'christmas': 1824,
#  'hmmm': 3474,
#  'guess': 3286,
#  'go': 3178,
#  'kb': 3918,
#  'power': 5367,
#  'yoga': 7705,
#  'haha': 3312,
#  'dunno': 2510,
#  'tahan': 6696,
#  'anot': 987,
#  'thk': 6859,
#  'got': 3219,
#  'lo': 4181,
#  'oso': 5019,
#  'forgot': 2966,
#  'liao': 4107,
#  'whos': 7509,
#  'am': 939,
#  'wen': 7464,
#  'lovable': 4244,
#  'bcums': 1273,
#  'angry': 975,
#  'wid': 7516,
#  'dnt': 2392,
#  'seriously': 6047,
#  'coz': 2064,
#  'being': 1314,
#  'most': 4605,
#  'childish': 1797,
#  'way': 7420,
#  'showing': 6151,
#  'deep': 2235,
#  'affection': 850,
#  'care': 1666,
#  'kettoda': 3931,
#  'manda': 4359,
#  'nice': 4785,
#  'da': 2163,
#  'write': 7626,
#  'msg': 4630,
#  'put': 5531,
#  'dictionary': 2321,
#  'mode': 4567,
#  'cover': 2061,
#  'screen': 5978,
#  'hand': 3327,
#  'gently': 3125,
#  'remove': 5725,
#  'interesting': 3721,
#  'still': 6500,
#  'working': 7601,
#  'time': 6905,
#  'tried': 7042,
#  'adding': 818,
#  'zeros': 7741,
#  'was': 7398,
#  'savings': 5943,
#  'checking': 1772,
#  'germany': 3132,
#  'only': 4962,
#  'pence': 5155,
#  'minute': 4510,
#  'fixed': 2894,
#  'line': 4142,
#  'via': 7282,
#  'access': 782,
#  'number': 4868,
#  '0844': 60,
#  '861': 687,
#  '85': 678,
#  'no': 4808,
#  'prepayment': 5406,
#  'direct': 2353,
#  '08712402578': 104,
#  'immediately': 3638,
#  'there': 6836,
#  'an': 964,
#  'urgent': 7204,
#  'message': 4467,
#  'waiting': 7364,
#  'see': 6003,
#  'forwarding': 2979,
#  'proof': 5481,
#  'lou': 4239,
#  'took': 6982,
#  'long': 4211,
#  'reply': 5744,
#  'left': 4079,
#  'mobile': 4557,
#  'lancaster': 4015,
#  'bak': 1208,
#  'neway': 4774,
#  'im': 3627,
#  'couldn': 2048,
#  'make': 4345,
#  'hun': 3565,
#  'rs': 5861,
#  'wan': 7381,
#  'too': 6981,
#  'early': 2526,
#  'lei': 4086,
#  'outside': 5038,
#  'wun': 7643,
#  'home': 3490,
#  'neva': 4768,
#  'mind': 4496,
#  'then': 6830,
#  'hhahhaahahah': 3441,
#  'rofl': 5836,
#  'wtf': 7638,
#  'nig': 4789,
#  'leonardo': 4094,
#  'room': 5844,
#  'something': 6328,
#  'oh': 4926,
#  'by': 1603,
#  'food': 2946,
#  'fridge': 3017,
#  'out': 5031,
#  'meal': 4420,
#  'tonight': 6976,
#  'daddy': 2168,
#  'scream': 5975,
#  'pleasure': 5270,
#  'going': 3191,
#  'slap': 6238,
#  'ass': 1108,
#  'dick': 2319,
#  'how': 3537,
#  'didn': 2324,
#  'include': 3661,
#  'these': 6838,
#  'details': 2295,
#  'are': 1052,
#  'awake': 1171,
#  'snow': 6299,
#  'dear': 2214,
#  'ok': 4930,
#  'fool': 2947,
#  'dont': 2428,
#  'cheat': 1765,
#  'others': 5022,
#  'seems': 6009,
#  'unnecessarily': 7171,
#  'hostile': 3524,
#  'someone': 6322,
#  'asked': 1101,
#  'dating': 2198,
#  'service': 6050,
#  'contact': 1994,
#  'cant': 1654,
#  'who': 7505,
#  '09058097189': 184,
#  'be': 1276,
#  'revealed': 5794,
#  'pobox': 5287,
#  'ls15hb': 4266,
#  '150p': 306,
#  'hey': 3438,
#  'cutie': 2154,
#  'goes': 3186,
#  'wales': 7367,
#  'kinda': 3954,
#  'like': 4127,
#  'hills': 3450,
#  'shit': 6116,
#  'avent': 1164,
#  'killed': 3949,
#  'myself': 4685,
#  'what': 7483,
#  'sunday': 6613,
#  'holiday': 3485,
#  'work': 7599,
#  'gotta': 3223,
#  'spoke': 6416,
#  'maneesha': 4363,
#  'satisfied': 5933,
#  'experience': 2731,
#  'toll': 6960,
#  'free': 3000,
#  'watch': 7406,
#  'films': 2858,
#  'hours': 3531,
#  'called': 1625,
#  'whole': 7506,
#  'family': 2781,
#  'wake': 7365,
#  'cause': 1700,
#  'started': 6465,
#  'jetton': 3837,
#  'ave': 1162,
#  'wana': 7382,
#  'give': 3161,
#  'one': 4956,
#  'sounds': 6360,
#  'keep': 3921,
#  'posted': 5354,
#  'yeah': 7682,
#  'basically': 1244,
#  'any': 998,
#  'week': 7446,
#  'get': 3133,
#  'away': 1174,
#  'mom': 4577,
#  'amp': 956,
#  'before': 1304,
#  'eek': 2553,
#  'especially': 2659,
#  'since': 6194,
#  'american': 944,
#  'pie': 5224,
#  'minutes': 4511,
#  'stop': 6513,
#  'singing': 6199,
#  'maybe': 4412,
#  'fucking': 3048,
#  'wouldn': 7620,
#  'problem': 5449,
#  'need': 4742,
#  'ask': 1099,
#  'means': 4424,
#  'door': 2435,
#  'objection': 4892,
#  'bf': 1347,
#  'coming': 1924,
#  'why': 7512,
#  'come': 1918,
#  'search': 5987,
#  'job': 3845,
#  'aight': 885,
#  'money': 4584,
#  'back': 1196,
#  '2morro': 401,
#  'half': 3318,
#  'term': 6778,
#  'over': 5044,
#  '2nite': 408,
#  'sexy': 6066,
#  'passion': 5121,
#  'b4': 1183,
#  'chat': 1758,
#  '09099726481': 252,
#  'dena': 2264,
#  'calls': 1633,
#  'minmobsmorelkpobox177hp51fl': 4503,
#  'wiskey': 7556,
#  'brandy': 1494,
#  'rum': 5876,
#  'gin': 3154,
#  'beer': 1301,
#  'vodka': 7323,
#  'scotch': 5969,
#  'shampain': 6082,
#  'wine': 7537,
#  'kudi': 3988,
#  'yarasu': 7676,
#  'dhina': 2309,
#  'vaazhthukkal': 7240,
#  'friday': 3015,
#  'wait': 7361,
#  'superior': 6624,
#  '000': 1,
#  'bonus': 1434,
#  'caller': 1626,
#  '08': 42,
#  '03': 13,
#  '0871': 93,
#  '4719': 503,
#  '523': 548,
#  'box95qu': 1480,
#  'bt': 1552,
#  'national': 4718,
#  'rate': 5598,
#  'hmm': 3473,
#  'uncle': 7136,
#  'informed': 3689,
#  'he': 3381,
#  'paying': 5139,
#  'school': 5961,
#  'directly': 2354,
#  'buy': 1592,
#  'made': 4322,
#  'constant': 1992,
#  'thought': 6869,
#  'having': 3378,
#  'visit': 7312,
#  'till': 6903,
#  'kiss': 3962,
#  'sitting': 6215,
#  'mu': 4646,
#  'everyone': 2687,
#  'suite': 6600,
#  'shower': 6149,
#  'nigh': 4791,
#  'aha': 876,
#  'drive': 2474,
#  'read': 5621,
#  'cool': 2020,
#  'ready': 5625,
#  'said': 5902,
#  'matter': 4402,
#  'saying': 5948,
#  'mate': 4394,
#  'rv': 5886,
#  'hav': 3370,
#  'hol': 3481,
#  'say': 5945,
#  'haven': 3374,
#  'sent': 6037,
#  'ages': 871,
#  'driving': 2477,
#  'stay': 6476,
#  'roads': 5827,
#  'rvx': 5887,
#  'probably': 5448,
#  'tomorrow': 6967,
#  'even': 2677,
#  'later': 4039,
#  'six': 6219,
#  'chances': 1736,
#  'win': 7530,
#  '20': 342,
#  'pounds': 5363,
#  'txt': 7094,
#  'csh11': 2112,
#  '87575': 699,
#  'cost': 2036,
#  '6days': 600,
#  '16': 317,
#  'tsandcs': 7064,
#  'apply': 1029,
#  'hl': 3468,
#  'info': 3686,
#  'didnt': 2325,
#  'sometext': 6326,
#  'missing': 4525,
#  'again': 863,
#  'about': 765,
#  'earlier': 2524,
#  'putting': 5534,
#  'fires': 2882,
#  'talk': 6707,
#  'actually': 811,
#  'lol': 4204,
#  'chance': 1735,
#  '250': 367,
#  'spree': 6432,
#  '80878': 651,
#  'custcare': 2145,
#  '08715705022': 126,
#  '1x150p': 340,
#  'wk': 7567,
#  'yep': 7692,
#  'pretty': 5419,
#  'sculpture': 5981,
#  'ate': 1123,
#  'prices': 5425,
#  'mean': 4422,
#  'girl': 3155,
#  'happy': 3349,
#  'difficult': 2335,
#  'girls': 3158,
#  'companion': 1935,
#  'lover': 4250,
#  'chef': 1781,
#  'listener': 4163,
#  'organizer': 5011,
#  'boyfriend': 1484,
#  'clean': 1848,
#  'sympathetic': 6679,
#  'athletic': 1124,
#  'warm': 7392,
#  'courageous': 2057,
#  'determined': 2296,
#  'dependable': 2273,
#  'intelligent': 3715,
#  'psychologist': 5503,
#  'pest': 5188,
#  'exterminator': 2745,
#  'psychiatrist': 5501,
#  'healer': 3390,
#  'stylist': 6568,
#  'driver': 2475,
#  'aaniye': 751,
#  'pudunga': 5510,
#  'venaam': 7272,
#  'doing': 2417,
#  'trouble': 7049,
#  '4d': 512,
#  'dad': 2167,
#  '1405': 297,
#  '1680': 318,
#  '1843': 321,
#  'big': 1356,
#  'small': 6262,
#  'sat': 5931,
#  'sun': 6612,
#  'questions': 5550,
#  'mistake': 4531,
#  'eat': 2537,
#  'jap': 3811,
#  'aft': 856,
#  'lect': 4076,
#  'wat': 7405,
#  '12': 282,
#  'rite': 5823,
#  'pa': 5063,
#  'hop': 3506,
#  'ard': 1051,
#  'ya': 7668,
#  'abt': 773,
#  'muz': 4676,
#  'discuss': 2369,
#  'though': 6868,
#  'shd': 6093,
#  'fun': 3059,
#  'bar': 1228,
#  'town': 7008,
#  'sound': 6358,
#  'trying': 7062,
#  'little': 4169,
#  'private': 5440,
#  '2003': 345,
#  'account': 792,
#  'statement': 6472,
#  '07973788240': 40,
#  'shows': 6154,
#  '800': 638,
#  'un': 7132,
#  'redeemed': 5673,
#  'points': 5307,
#  '08715203649': 121,
#  'identifier': 3606,
#  'code': 1892,
#  '40533': 479,
#  'expires': 2734,
#  '31': 438,
#  '10': 258,
#  '04': 14,
#  'aiyah': 893,
#  'lor': 4225,
#  'tv': 7083,
#  'until': 7180,
#  'phone': 5204,
#  'pick': 5216,
#  'right': 5810,
#  'lov': 4243,
#  'hurt': 3575,
#  'truth': 7059,
#  'wil': 7523,
#  'tolerat': 6959,
#  'bcs': 1271,
#  'never': 4770,
#  'comfort': 1922,
#  'lie': 4114,
#  'gud': 3283,
#  'ni8': 4783,
#  'sweet': 6660,
#  'dreams': 2466,
#  'sir': 6206,
#  've': 7265,
#  'spent': 6399,
#  '2geva': 392,
#  'bin': 1366,
#  'mint': 4508,
#  'baby': 1191,
#  'xxxx': 7662,
#  'where': 7494,
#  'yuou': 7733,
#  'getting': 3141,
#  'pc': 5144,
#  'spot': 6428,
#  'would': 7618,
#  'explicit': 2737,
#  'sex': 6063,
#  '30': 425,
#  'secs': 5998,
#  'ring': 5815,
#  '02073162414': 10,
#  'costs': 2039,
#  '20p': 353,
#  'min': 4494,
#  'gsex': 3277,
#  '2667': 372,
#  'wc1n': 7422,
#  '3xx': 473,
#  'let': 4100,
#  'try': 7060,
#  'lolnice': 4205,
#  'went': 7467,
#  'fish': 2886,
#  'water': 7411,
#  'reason': 5639,
#  'spoken': 6417,
#  'year': 7683,
#  'anyways': 1011,
#  'great': 3254,
#  'best': 1333,
#  'exam': 2709,
#  'significant': 6178,
#  'worry': 7608,
#  'lmao': 4180,
#  'well': 7461,
#  'jst': 3874,
#  'change': 1737,
#  'tat': 6726,
#  'sindu': 6196,
#  'birla': 1370,
#  'soft': 6309,
#  'carlos': 1678,
#  'few': 2835,
#  'asking': 1103,
#  'weekend': 7448,
#  'testing': 6787,
#  'sayy': 5950,
#  'borrow': 1453,
#  'bag': 1202,
#  'england': 2611,
#  'macedonia': 4311,
#  'goals': 3182,
#  'team': 6746,
#  'news': 4777,
#  '87077': 693,
#  'eg': 2557,
#  'scotland': 5970,
#  '4txt': 528,
#  'ú1': 7748,
#  'poboxox36504w45wq': 5299,
#  'clothes': 1868,
#  'jewelry': 3838,
#  'trips': 7044,
#  'babe': 1188,
#  'repeat': 5738,
#  'instructions': 3713,
#  'road': 5826,
#  'name': 4701,
#  'house': 3532,
#  'missed': 4523,
#  'ps': 5497,
#  'grown': 3272,
#  'ho': 3479,
#  'use': 7219,
#  'type': 7107,
#  'words': 7598,
#  'late': 4036,
#  'slept': 6246,
#  'enjoy': 2613,
#  'lesson': 4098,
#  'teasing': 6751,
#  'xx': 7658,
#  'rather': 5600,
#  'prominent': 5472,
#  'bite': 1379,
#  'mark': 4373,
#  'cheek': 1775,
#  'peach': 5148,
#  'cake': 1611,
#  'tasts': 6725,
#  'lush': 4282,
#  'yourself': 7719,
#  'practice': 5377,
#  'real': 5626,
#  'fuck': 3045,
#  'dropped': 2481,
#  'cell': 1718,
#  'down': 2450,
#  'stairs': 6450,
#  'alright': 929,
#  'phews': 5200,
#  'sec': 5991,
#  'believe': 1315,
#  'attached': 1131,
#  'seeing': 6005,
#  'every': 2683,
#  'teach': 6741,
#  'midnight': 4482,
#  'funk': 3062,
#  'fone': 2942,
#  'weekly': 7450,
#  'new': 4773,
#  'tone': 6969,
#  'tones2u': 6971,
#  'ringtones': 5819,
#  'co': 1882,
#  'uk': 7123,
#  'original': 5014,
#  'tones': 6970,
#  '3gbp': 459,
#  'network': 4765,
#  'operator': 4981,
#  'rates': 5599,
#  'yunny': 7731,
#  'walking': 7373,
#  'citylink': 1833,
#  'faster': 2796,
#  'hungry': 3568,
#  'plm': 5273,
#  'aiyar': 894,
#  'poor': 5327,
#  'jia': 3840,
#  'think': 6849,
#  'theory': 6833,
#  'argument': 1062,
#  'wins': 7544,
#  'situation': 6216,
#  'loses': 4228,
#  'person': 5179,
#  'argue': 1061,
#  'kick': 3939,
#  'always': 937,
#  'correct': 2030,
#  'eerie': 2554,
#  'nokia': 4818,
#  'rply': 5859,
#  'title': 6920,
#  '8007': 640,
#  'dracula': 2459,
#  'titles': 6921,
#  'ghost': 3144,
#  'addamsfa': 815,
#  'munsters': 4664,
#  'exorcist': 2724,
#  'twilight': 7088,
#  'getzed': 3142,
#  'pobox36504w45wq': 5294,
#  'vl': 7320,
#  'adsense': 835,
#  'approved': 1038,
#  'wanted': 7387,
#  'legal': 4082,
#  'advice': 841,
#  'gary': 3095,
#  'split': 6413,
#  'trip': 7043,
#  'ptbo': 5505,
#  'gonnamissu': 3201,
#  'much': 4648,
#  'il': 3621,
#  'postcard': 5352,
#  'buttheres': 1590,
#  'aboutas': 766,
#  'merememberin': 4463,
#  'asthere': 1115,
#  'ofsi': 4922,
#  'breakin': 1505,
#  'his': 3459,
#  'yaxx': 7678,
#  'crazy': 2081,
#  'ar': 1046,
#  'married': 4379,
#  'gd': 3110,
#  'looking': 4218,
#  'guys': 3300,
#  'frens': 3010,
#  'korean': 3982,
#  'leona': 4093,
#  'fave': 2805,
#  'dun': 2508,
#  'thinking': 6852,
#  'mayb': 4411,
#  'prob': 5447,
#  'people': 5160,
#  'game': 3082,
#  'mall': 4352,
#  'iouri': 3742,
#  'kaila': 3899,
#  'possession': 5344,
#  'offense': 4911,
#  'round': 5851,
#  'men': 4454,
#  'looks': 4219,
#  'scrumptious': 5980,
#  'welcome': 7459,
#  'date': 2195,
#  'giving': 3164,
#  'calling': 1631,
#  '08719839835': 154,
#  'future': 3069,
#  'mgs': 4476,
#  'billed': 1360,
#  'daily': 2171,
#  'cancel': 1646,
#  '89123': 712,
#  'telling': 6763,
#  'coulda': 2047,
#  'valentine': 7244,
#  'wasn': 7400,
#  'nothing': 4847,
#  'princess': 5431,
#  'worse': 7610,
#  'uses': 7223,
#  'stops': 6519,
#  'better': 1339,
#  'him': 3452,
#  'complete': 1945,
#  'address': 819,
#  'almost': 925,
#  'gas': 3096,
#  'dude': 2500,
#  'should': 6142,
#  'sup': 6621,
#  'sign': 6175,
#  'maturity': 4405,
#  'start': 6464,
#  'things': 6848,
#  'understanding': 7147,
#  'bslvyl': 1548,
#  'blankets': 1393,
#  'sufficient': 6595,
#  'thx': 6892,
#  'mins': 4507,
#  'had': 3310,
#  'somewhere': 6332,
#  'sister': 6209,
#  'earn': 2527,
#  'than': 6804,
#  'whatever': 7484,
#  'lunch': 4279,
#  'man': 4354,
#  '8am': 717,
#  'exactly': 2708,
#  'could': 2046,
#  'chechi': 1767,
#  'otherwise': 5023,
#  'part': 5108,
#  'na': 4690,
#  'tuition': 7073,
#  'finished': 2873,
#  'yet': 7697,
#  'slide': 6249,
#  'enough': 2619,
#  'cardiff': 1663,
#  'cold': 1899,
#  'radiator': 5566,
#  'aiyo': 895,
#  'bit': 1376,
#  'pai': 5071,
#  'seh': 6012,
#  'noe': 4812,
#  'scared': 5955,
#  'rem': 5710,
#  'die': 2327,
#  'hee': 3406,
#  'become': 1288,
#  'lookin': 4217,
#  'oredi': 5006,
#  'leh': 4085,
#  'law': 4051,
#  'month': 4590,
#  'abiola': 761,
#  'medical': 4431,
#  'missions': 4527,
#  'nigeria': 4790,
#  'ahead': 877,
#  'watts': 7416,
#  'bloomberg': 1412,
#  'center': 1720,
#  '447797706009': 493,
#  'careers': 1670,
#  'busy': 1587,
#  'forward': 2977,
#  'finally': 2864,
#  'di': 2312,
#  'yijue': 7701,
#  'pm': 5283,
#  'esaplanade': 2654,
#  'login': 4198,
#  'anything': 1007,
#  'rock': 5831,
#  'yr': 7725,
#  ...}

# %%
v.get_feature_names_out()[1102]
# Out:
# 'askin'

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.where(X_train_np[0] != 0)
# Out:
# (array([1122, 1642, 3279, 4073, 4268, 5267, 6304, 6815, 7424, 7694]),)

# %%
X_train[:4][1233]
# Out:
# "1's finish meeting call me."

# %%
X_train_np[0][1063]
# Out:
# 0

# %%
X_train_np[0][1642]
# Out:
# 1

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       962
#            1       0.97      0.88      0.92       153
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.95      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 1])

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       962
#            1       0.97      0.88      0.92       153
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.95      1115
# weighted avg       0.98      0.98      0.98      1115
